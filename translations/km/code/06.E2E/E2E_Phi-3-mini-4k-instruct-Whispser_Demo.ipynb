# %% [markdown]
# ## ឆាតប៊ូតអន្តរកម្ម Phi 3 Mini 4K Instruct ជាមួយ Whisper
#
# ### ការណែនាំ:
# ឆាតប៊ូតអន្តរកម្ម Phi 3 Mini 4K Instruct គឺជាឧបករណ៍មួយដែលអនុញ្ញាតឱ្យអ្នកប្រើប្រាស់អាចអន្តរកម្មជាមួយកម្មវិធីបង្ហាញ Microsoft Phi 3 Mini 4K Instruct ដោយប្រើការបញ្ចូលតាមអត្ថបទ ឬសំឡេង។ ឆាតប៊ូតនេះអាចប្រើសម្រាប់ភារកិច្ចនានា ដូចជា ការប្រែសម្រួល ព័ត៌មានអាកាសធាតុ និងការប្រមូលព័ត៌មានទូទៅ។

# %%
#Install required Python Packages
# !pip install accelerate
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install flash-attn --no-build-isolation', env={'FLASH_ATTENTION_SKIP_CUDA_BUILD': "TRUE"}, shell=True
# !pip install transformers
# !pip install wheel
# !pip install gradio
# !pip install pydub==0.25.1
# !pip install edge-tts
# !pip install openai-whisper==20231117
# !pip install ffmpeg==1.4
# from IPython.display import clear_output
# clear_output()

# %%
# Checking to see if Cuda support is available 
# Output True = Cuda
# Output False = No Cuda (installing Cuda will be required to run the model on GPU)
import os 
import torch
print(torch.cuda.is_available())

# %% [markdown]
# [បង្កើត Access Token របស់អ្នកសម្រាប់ Huggingface](https://huggingface.co/settings/tokens)
#
# បង្កើត token ថ្មីមួយ
# ផ្ដល់ឈ្មោះថ្មី
# ជ្រើសសិទ្ធិសរសេរ
# ចម្លង token ហើយរក្សាទុកវាក្នុងកន្លែងដែលមានសុវត្ថិភាព

# %% [markdown]
# កូដ Python ខាងក្រោមនេះ អនុវត្តពីរជំហានសំខាន់៖ នាំចូលម៉ូឌុល `os` និង កំណត់អថេរបរិស្ថាន។
#
# 1. Importing the `os` module:
#    - ម៉ូឌុល `os` ក្នុង Python ផ្តល់មធ្យោបាយក្នុងការទំនាក់ទំនងជាមួយប្រព័ន្ធប្រតិបត្តិការ។ វាអនុញ្ញាតឱ្យអ្នកធ្វើបេសកកម្មនានាស្ថិតក្នុងប្រព័ន្ធប្រតិបត្តិការ ដូចជា ចូលប្រើអថេរបរិស្ថាន ការងារជាមួយឯកសារ និងថតឯកសារ ជាដើម។
#    - នៅក្នុងកូដនេះ ម៉ូឌុល `os` ត្រូវបាននាំចូលដោយប្រើពាក្យបញ្ជា `import`។ ពាក្យបញ្ជានេះធ្វើឱ្យមុខងារនានារបស់ម៉ូឌុល `os` មានស្រាប់សម្រាប់ប្រើនៅក្នុងស្គ្រីប Python បច្ចុប្បន្ន។
#
# 2. Setting an environment variable:
#    - អថេរបរិស្ថានគឺជាតម្លៃដែលកម្មវិធីដែលដំណើរការលើប្រព័ន្ធប្រតិបត្តិការ អាចចូលដើម្បីយកបាន។ នេះជាវិធីក្នុងការផ្ទុកការកំណត់រចនាសម្ព័ន្ធ ឬព័ត៌មានផ្សេងៗដែលកម្មវិធីច្រើនអាចប្រើបាន។
#    - នៅក្នុងកូដនេះ អថេរបរិស្ថានថ្មីត្រូវបានកំណត់ដោយប្រើដិកស្យូណារី `os.environ`។ គ្រាប់សម្គាល់ (key) នៃដិកស្យូណារីគឺ `'HF_TOKEN'` ហើយតម្លៃត្រូវបានផ្ដល់ពីអថេរ `HUGGINGFACE_TOKEN`។
#    - អថេរ `HUGGINGFACE_TOKEN` ត្រូវបានកំណត់ខាងលើសណ្តាប់កូដនេះ ហើយវាត្រូវបានផ្ដល់តម្លៃជាខ្សែអក្សរ `"hf_**************"` ដោយប្រើស’intégrស៊ីនតាក់ `#@param`។ ស៊ីនតាក់នេះភាគច្រើនត្រូវបានប្រើនៅក្នុង Jupyter notebooks ដើម្បីឱ្យមានការបញ្ចូលពីអ្នកប្រើ និងកំណត់ប៉ារ៉ាម៉ែត្រ ដោយផ្ទាល់ក្នុងចំណុចបង្ហាញនៃ notebook។
#    - ដោយការកំណត់អថេរ `'HF_TOKEN'` នេះ វាអាចត្រូវបានចូលដល់ដោយផ្នែកផ្សេងៗនៃកម្មវិធី ឬកម្មវិធីផ្សេងទៀតដែលកំពុងដំណើរការនៅលើប្រព័ន្ធប្រតិបត្តិការដូចគ្នា។
#
# Overall, this code imports the `os` module and sets an environment variable named `'HF_TOKEN'` with the value provided in the `HUGGINGFACE_TOKEN` variable.

# %%
import os
# set the Hugging Face Token from 
# add the Hugging Face Token to the environment variables
HUGGINGFACE_TOKEN = "Enter Hugging Face Key" #@param {type:"string"}
os.environ['HF_TOKEN']HUGGINGFACE_TOKEN

# %% [markdown]
# ឧទាហរណ៍កូដនេះបានកំណត់មុខងារមួយដែលមានឈ្មោះ clear_output ដែលប្រើសម្រាប់សម្អាតលទ្ធផលនៃសែលបច្ចុប្បន្ននៅក្នុង Jupyter Notebook ឬ IPython។ យើងចែកបំបែកកូដនេះ និងយល់ពីមុខងាររបស់វា៖
#
# មុខងារ clear_output ទទួលប៉ារ៉ាម៉ែត្រមួយដែលមានឈ្មោះ wait ដែលជាតម្លៃ boolean។ ជាធម្មតា wait ត្រូវបានកំណត់ជា False។ ប៉ារ៉ាម៉ែត្រនេះកំណត់ថា មុខងារនោះគួរតែរង់ចាំរហូតដល់មានលទ្ធផលថ្មីសម្រាប់ជំនួសលទ្ធផលដែលមានស្រាប់ មុននឹងសម្អាតវា ឬអត់។
#
# មុខងារនេះត្រូវបានប្រើសម្រាប់សម្អាតលទ្ធផលនៃសែលបច្ចុប្បន្ន។ នៅក្នុង Jupyter Notebook ឬ IPython ពេលដែលសែលបង្កើតលទ្ធផល ដូចជា អត្ថបទដែលបានបោះពុម្ព ឬ គំនូរស្ថិតិ លទ្ធផលនោះនឹងបង្ហាញនៅក្រោមសែល។ មុខងារ clear_output អនុញ្ញាតឱ្យអ្នកសម្អាតលទ្ធផលនោះបាន។
#
# ការអនុវត្តន៍នៃមុខងារនេះមិនត្រូវបានបញ្ចូលក្នុងឧទាហរណ៍កូដនេះ ដូចដែលបង្ហាញដោយជួរគន្លង (...). ជួរគន្លងនោះជាតំណាងសម្រាប់ទីតាំងទុកសម្រាប់កូដពិតដែលអនុវត្តការសម្អាតលទ្ធผล។ ការអនុវត្តន៍អាចពាក់ព័ន្ធនឹងការទំនាក់ទំនងជាមួយ API របស់ Jupyter Notebook ឬ IPython ដើម្បីដកលទ្ធផលដែលមានស្រាប់ចេញពីសែល។
#
# សរុប មុខងារនេះផ្តល់វិធីងាយស្រួលសម្រាប់សម្អាតលទ្ធផលនៃសែលបច្ចុប្បន្ននៅក្នុង Jupyter Notebook ឬ IPython ដែលធ្វើឱ្យងាយស្រួលក្នុងការគ្រប់គ្រង និងធ្វើអាប់ដេតលទ្ធផលដែលបង្ហាញ ខណៈពេលធ្វើសកម្មភាពកូដអន្តរកម្ម។

# %%
# Download Phi-3-mini-4k-instruct model & Whisper Tiny
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

#whisper for speech to text()
import whisper
select_model ="tiny" # ['tiny', 'base']
whisper_model = whisper.load_model(select_model)

#from IPython.display import clear_output
#clear_output()

# %% [markdown]
# អនុវត្ត​ការ​បំលែង​អត្ថបទ​ទៅ​ជា​សម្លេង (TTS) using the Edge TTS service. Let's go through the relevant function implementations one by one:
#
# 1. `calculate_rate_string(input_value)`: មុខងារ​នេះ​ទទួលបាន​តម្លៃ​បញ្ចូល​មួយ ហើយ​គណនាសំណងនៃអត្រា (rate string) សម្រាប់សម្លេង TTS។ តម្លៃ​បញ្ចូល​ជាកំណត់ល្បឿន​ដែល​ចង់បាន សម្រាប់ការនិយាយ ដែលតម្លៃ 1 បង្ហាញល្បឿនធម្មតា។ មុខងារ​នេះ​គណនា rate string ដោយដក 1 ចេញពីតម្លៃបញ្ចូល ក៏បូកគុណលទ្ធផលនោះ ជាមួយ 100 ហើយកំណត់​សញ្ញា ដោយផ្អែកលើថាតើតម្លៃបញ្ចូល >= 1 ឬអន្ថែម។ មុខងារ​ត្រឡប់តម្លៃ rate string ក្នុងទ្រង់ទ្រាយ "{sign}{rate}".
#
# 2.`make_chunks(input_text, language)`: មុខងារ​នេះ​ទទួល​អត្ថបទ​បញ្ចូល​មួយ និងភាសា​ជា​ប៉ារ៉ាម៉ែត្រ។ វាបំបែក​អត្ថបទ​បញ្ចូល​ទៅជា​ផ្នែកៗ ដោយយោងតាម​ច្បាប់​ដែលពាក់ព័ន្ធ​នឹងភាសា។ ក្នុង​ការ​អនុវត្ត​នេះ ប្រសិនបើ​ភាសា​គឺ "English" មុខងារ​នឹងបំបែកអត្ថបទនៅគ្រប់ចំណុច("." ) ហើយលុបចោលចន្លោះ​នៅដើម និងចុង។ បន្ទាប់មក វាបន្ថែមចុចសញ្ញា "." ទៅលើផ្នែកនីមួយៗ ហើយត្រឡប់បញ្ជីផ្នែកដែលបានត្រង។
#
# 3. `tts_file_name(text)`: មុខងារ​នេះ​បង្កើត​ឈ្មោះឯកសារ​សម្រាប់​សម្លេង TTS ដោយផ្អែកលើអត្ថបទ​បញ្ចូល។ វាធ្វើការបម្លែងច្រើនលើអត្ថបទ៖ លុបចំណុចចុង (បើមាន), បម្លែងអត្ថបទទៅអក្សរតូច, លុប​ចន្លោះ​នៅដើម និងចុង, និងជំនួសចន្លោះដោយអង់ធ័រ "_". បន្ទាប់មក វាខ្ជះអត្ថបទទៅអតិបរមា 25 តួអក្សរ (បើវាជាច្រើន) ឬប្រើអត្ថបទពេញលេញ ប្រសិនបើវាចាប់សូន្យ។ ចុងក្រោយ វាបង្កើតខ្សែអក្សរចៃដន្យដោយប្រើម៉ូឌុល [`uuid`] ហើយផ្គូផ្គងវាជាមួយអត្ថបទដែលបានខ្ជះ ដើម្បីបង្កើតឈ្មោះឯកសារក្នុងទ្រង់ទ្រាយ "/content/edge_tts_voice/{truncated_text}_{random_string}.mp3".
#
# 4. `merge_audio_files(audio_paths, output_path)`: មុខងារ​នេះ​រួមបញ្ចូល​ឯកសារ​សម្លេង​ជា​ច្រើន​ទៅជា​ឯកសារ​សម្លេង​មួយ។ វាទទួលបញ្ជី​ផ្លូវឯកសារ​សម្លេង និងផ្លូវចេញ (output path) ជា​ប៉ារ៉ាម៉ែត្រ។ មុខងារ​នេះ​ដាក់ចាប់ផ្តើម `AudioSegment` ទទេ​មួយ​ដែលឈ្មោះ [`merged_audio`]. បន្ទាប់មក វាធ្វើលំដាប់តាមគ្រប់ផ្លូវឯកសារ​សម្លេង មួយៗ ទាញ​ឯកសារ​សម្លេងដោយប្រើវិធីសាស្ត្រ `AudioSegment.from_file()` ពីបណ្ណាល័យ `pydub` ហើយភ្ជាប់ឯកសារ​សម្លេង​បច្ចុប្បន្ន​ទៅក្នុង​អូបជექტ [`merged_audio`]. ចុងក្រោយ វានាំចេញសម្លេងដែលបានរួមគ្នា​ទៅផ្លូវចេញដែលបានបញ្ជាក់ ក្នុងទ្រង់ទ្រាយ MP3។
#
# 5. `edge_free_tts(chunks_list, speed, voice_name, save_path): This function performs the TTS operation using the Edge TTS service.` វាទទួលបញ្ជីផ្នែកអត្ថបទ, ល្បឿននៃការនិយាយ, ឈ្មោះសម្លេង, និងផ្លូវសម្រាប់រក្សាទុកជាប៉ារ៉ាម៉ែត្រ។ ប្រសិនបើចំនួនផ្នែក​ច្រើនជាង 1 មុខងារ​នឹងបង្កើតថតសម្រាប់ផ្ទុកឯកសារ​សម្លេងនៃផ្នែកនីមួយៗ។ បន្ទាប់មក វាច្រៀងតាមផ្នែកនីមួយៗ បង្កើតបញ្ជា Edge TTS ដោយប្រើ `calculate_rate_string()'` មុខងារ, ឈ្មោះសម្លេង និងអត្ថបទផ្នែក ហើយដំណើរការបញ្ជានោះដោយប្រើ `os.system()`. ប្រសិនបើការប Executes បញ្ជាជោគជ័យ វានឹងបន្ថែមផ្លូវឯកសារ​ដែលបានបង្កើតទៅក្នុងបញ្ជីមួយ។ បន្ទាប់ពីរាល់ផ្នែកបានដំណើរការ វា​រួមបញ្ចូល​ឯកសារ​សម្លេងនីមួយៗដោយប្រើ `merge_audio_files()` ហើយរក្សាទុកសម្លេងរួមទៅផ្លូវដែលបានបញ្ជាក់។ ប្រសិនបើមានតែមួយផ្នែក វានឹងបង្កើតបញ្ជា Edge TTS តែម្តង និងរក្សាសម្លេងទៅផ្លូវដែលបានកំណត់។ ចុងក្រោយ វាត្រឡប់ផ្លូវរក្សាទុកនៃឯកសារ​សម្លេង​ដែលបានបង្កើត។
#
# 6. `random_audio_name_generate()`: មុខងារ​នេះ​បង្កើត​ឈ្មោះឯកសារ​សម្លេងដោយចៃដន្យដោយប្រើម៉ូឌុល [`uuid`]។ វាបង្កើត UUID ចៃដន្យ បម្លែងវាទៅជាសរសេរ ទាញ 8 តួអក្សរដំបូង បន្ថែមផ្នែកបន្ថែម ".mp3" ហើយត្រឡប់ឈ្មោះឯកសារ​ចៃដន្យ។
#
# 7. `talk(input_text)`: មុខងារ​នេះជា​ច្រកចូល​សំខាន់សម្រាប់អនុវត្ត TTS។ វាទទួលអត្ថបទបញ្ចូលមួយជាប៉ារ៉ាម៉ែត្រ។ វាចាប់ផ្តើមពិនិត្យប្រវែងអត្ថបទបញ្ចូល ដើម្បីកំណត់ថាតើវាជាសំណេីចវែង (>= 600 តួអក្សរ) ឬអត់។ ដោយផ្អែកលើប្រវែង និងតម្លៃខ្ទង់ `translate_text_flag` វាកំណត់ភាសា និងបង្កើតបញ្ជីផ្នែកអត្ថបទដោយប្រើ `make_chunks()`។ បន្ទាប់មក វាបង្កើតផ្លូវសម្រាប់រក្សាសម្លេងដោយប្រើ `random_audio_name_generate()`។ ចុងក្រោយ វាហៅ `edge_free_tts()` ដើម្បីអនុវត្ត TTS និងត្រឡប់ផ្លូវរក្សាទុកនៃឯកសារ​សម្លេង​ដែលបានបង្កើត។
#
# ជាសម្រុង មុខងារ​ទាំងនេះ​ធ្វើការ​រួមគ្នា ដើម្បីបំបែក​អត្ថបទ​បញ្ចូល​ជា​ផ្នែកៗ បង្កើតឈ្មោះឯកសារសម្រាប់សម្លេង អនុវត្ត​ការ TTS ដោយប្រើ​សេវា Edge TTS និងរួមបញ្ចូល​ឯកសារ​សម្លេង​នីមួយៗ​ទៅជា​ឯកសារ​តែមួយ។

# %%
#@title Edge TTS
def calculate_rate_string(input_value):
    rate = (input_value - 1) * 100
    sign = '+' if input_value >= 1 else '-'
    return f"{sign}{abs(int(rate))}"


def make_chunks(input_text, language):
    language="English"
    if language == "English":
      temp_list = input_text.strip().split(".")
      filtered_list = [element.strip() + '.' for element in temp_list[:-1] if element.strip() and element.strip() != "'" and element.strip() != '"']
      if temp_list[-1].strip():
          filtered_list.append(temp_list[-1].strip())
      return filtered_list


import re
import uuid
def tts_file_name(text):
    if text.endswith("."):
        text = text[:-1]
    text = text.lower()
    text = text.strip()
    text = text.replace(" ","_")
    truncated_text = text[:25] if len(text) > 25 else text if len(text) > 0 else "empty"
    random_string = uuid.uuid4().hex[:8].upper()
    file_name = f"/content/edge_tts_voice/{truncated_text}_{random_string}.mp3"
    return file_name


from pydub import AudioSegment
import shutil
import os
def merge_audio_files(audio_paths, output_path):
    # Initialize an empty AudioSegment
    merged_audio = AudioSegment.silent(duration=0)

    # Iterate through each audio file path
    for audio_path in audio_paths:
        # Load the audio file using Pydub
        audio = AudioSegment.from_file(audio_path)

        # Append the current audio file to the merged_audio
        merged_audio += audio

    # Export the merged audio to the specified output path
    merged_audio.export(output_path, format="mp3")

def edge_free_tts(chunks_list,speed,voice_name,save_path):
  # print(chunks_list)
  if len(chunks_list)>1:
    chunk_audio_list=[]
    if os.path.exists("/content/edge_tts_voice"):
      shutil.rmtree("/content/edge_tts_voice")
    os.mkdir("/content/edge_tts_voice")
    k=1
    for i in chunks_list:
      print(i)
      edge_command=f'edge-tts  --rate={calculate_rate_string(speed)}% --voice {voice_name} --text "{i}" --write-media /content/edge_tts_voice/{k}.mp3'
      print(edge_command)
      var1=os.system(edge_command)
      if var1==0:
        pass
      else:
        print(f"Failed: {i}")
      chunk_audio_list.append(f"/content/edge_tts_voice/{k}.mp3")
      k+=1
    # print(chunk_audio_list)
    merge_audio_files(chunk_audio_list, save_path)
  else:
    edge_command=f'edge-tts  --rate={calculate_rate_string(speed)}% --voice {voice_name} --text "{chunks_list[0]}" --write-media {save_path}'
    print(edge_command)
    var2=os.system(edge_command)
    if var2==0:
      pass
    else:
      print(f"Failed: {chunks_list[0]}")
  return save_path

# text = "This is Microsoft Phi 3 mini 4k instruct Demo" Simply update the text variable with the text you want to convert to speech
text = 'This is Microsoft Phi 3 mini 4k instruct Demo'  # @param {type: "string"}
Language = "English" # @param ['English']
# Gender of voice simply change from male to female and choose the voice you want to use
Gender = "Female"# @param ['Male', 'Female']
female_voice="en-US-AriaNeural"# @param["en-US-AriaNeural",'zh-CN-XiaoxiaoNeural','zh-CN-XiaoyiNeural']
speed = 1  # @param {type: "number"}
translate_text_flag  = False
if len(text)>=600:
  long_sentence = True
else:
  long_sentence = False

# long_sentence = False # @param {type:"boolean"}
save_path = ''  # @param {type: "string"}
if len(save_path)==0:
  save_path=tts_file_name(text)
if Language == "English" :
  if Gender=="Male":
    voice_name="en-US-ChristopherNeural"
  if Gender=="Female":
    voice_name=female_voice
    # voice_name="en-US-AriaNeural"


if translate_text_flag:
  input_text=text
  # input_text=translate_text(text, Language)
  # print("Translateting")
else:
  input_text=text
if long_sentence==True and translate_text_flag==True:
  chunks_list=make_chunks(input_text,Language)
elif long_sentence==True and translate_text_flag==False:
  chunks_list=make_chunks(input_text,"English")
else:
  chunks_list=[input_text]
# print(chunks_list)
# edge_save_path=edge_free_tts(chunks_list,speed,voice_name,save_path)
# from IPython.display import clear_output
# clear_output()
# from IPython.display import Audio
# Audio(edge_save_path, autoplay=True)

from IPython.display import clear_output
from IPython.display import Audio
if not os.path.exists("/content/audio"):
    os.mkdir("/content/audio")
import uuid
def random_audio_name_generate():
  random_uuid = uuid.uuid4()
  audio_extension = ".mp3"
  random_audio_name = str(random_uuid)[:8] + audio_extension
  return random_audio_name
def talk(input_text):
  global translate_text_flag,Language,speed,voice_name
  if len(input_text)>=600:
    long_sentence = True
  else:
    long_sentence = False

  if long_sentence==True and translate_text_flag==True:
    chunks_list=make_chunks(input_text,Language)
  elif long_sentence==True and translate_text_flag==False:
    chunks_list=make_chunks(input_text,"English")
  else:
    chunks_list=[input_text]
  save_path="/content/audio/"+random_audio_name_generate()
  edge_save_path=edge_free_tts(chunks_list,speed,voice_name,save_path)
  return edge_save_path


edge_save_path=talk(text)
Audio(edge_save_path, autoplay=True)

# %% [markdown]
# ការអនុវត្តន៍នៃមុខងារ​ពីរ: convert_to_text និង run_text_prompt, រួមទាំងការប្រកាសថ្លែងពីថ្នាក់ពីរ: str និង Audio។
#
# មុខងារ convert_to_text ទទួល audio_path ជា​បញ្ចូល ហើយបកប្រែសម្លេងជាអត្ថបទដោយប្រើម៉ូឌែលដែលមានឈ្មោះ whisper_model។ មុខងារនេះត្រូវពិនិត្យជាមុនថាកូនសញ្ញា gpu ត្រូវបានកំណត់ជា True ឬទេ។ ប្រសិនបើវា True, whisper_model នឹងត្រូវបានប្រើជាមួយប៉ារ៉ាម៉ែត្រដូចជា word_timestamps=True, fp16=True, language='English', និង task='translate'។ ប្រសិនបើ gpu គឺ False, whisper_model នឹងត្រូវបានប្រើជាមួយ fp16=False។ លទ្ធផលនៃការបកប្រែបន្ទាប់មកត្រូវបានរក្សាទុកក្នុងឯកសារដែលមានឈ្មោះ 'scan.txt' ហើយត្រូវបានហៅត្រឡប់មកជាអត្ថបទ។
#
# មុខងារ run_text_prompt ទទួល message និង chat_history ជា​បញ្ចូល។ វាប្រើ phi_demo ដើម្បីបង្កើតចម្លើយពី chatbot ដោយផ្អែកលើ message បញ្ចូល។ ចម្លើយដែលបានបង្កើតនោះត្រូវបានផ្ញើទៅមុខងារ talk ដែលបម្លែងចម្លើយទៅជាឯកសារ​សម្លេង និងត្រឡប់ផ្លូវឯកសារ។ ថ្នាក់ Audio ត្រូវបានប្រើសម្រាប់បង្ហាញ និងលេងឯកសារ​សម្លេង។ សម្លេងត្រូវបានបង្ហាញដោយប្រើមុខងារ display ពីម៉ូឌុល IPython.display, និងវត្ថុ Audio ត្រូវបានបង្កើតដោយមានប៉ារ៉ាម៉ែត្រ autoplay=True ដូច្នេះសម្លេងចាប់ផ្តើមលេងដោយស្វ័យប្រវត្តិ។ chat_history ត្រូវបានធ្វើបច្ចុប្បន្នភាពជាមួយ message បញ្ចូល និងចម្លើយដែលបានបង្កើត ហើយខ្សែអក្សរទទេមួយ និង chat_history ដែលបានធ្វើបច្ចុប្បន្នភាពត្រូវបានត្រឡប់។
#
# ថ្នាក់ str គឺជាថ្នាក់ built-in ក្នុង Python ដែលតំណាងឱ្យលំដាប់តួអក្សរ។ វាផ្តល់វិធីសាស្រ្តនានាសម្រាប់កែប្រែ និងដំណើរការខ្សែអក្សរ ដូចជា capitalize, casefold, center, count, encode, endswith, expandtabs, find, format, index, isalnum, isalpha, isascii, isdecimal, isdigit, isidentifier, islower, isnumeric, isprintable, isspace, istitle, isupper, join, ljust, lower, lstrip, partition, replace, removeprefix, removesuffix, rfind, rindex, rjust, rpartition, rsplit, rstrip, split, splitlines, startswith, strip, swapcase, title, translate, upper, zfill, និងផ្សេងទៀត។ វិធីសាស្រ្តទាំងនេះអនុញ្ញាតឱ្យអ្នកអនុវត្តប្រតិបត្តិការដូចជា ស្វែងរក ជំនួស ដាក់ទម្រង់ និងកែសម្រួលខ្សែអក្សរ។
#
# ថ្នាក់ Audio គឺជាថ្នាក់ប្តូរតាមបំណងដែលតំណាងឱ្យវត្ថុ​សម្លេង។ វាត្រូវបានប្រើដើម្បីបង្កើតកម្មវិធីចាក់សម្លេងនៅក្នុងបរិបទ Jupyter Notebook។ ថ្នាក់នេះទទួលប៉ារ៉ាម៉ែត្រផ្សេងៗដូចជា data, filename, url, embed, rate, autoplay, និង normalize។ ប៉ារ៉ាម៉ែត្រ data អាចជា numpy array, បញ្ជីនៃសំណំឧទាហរណ៍ (list of samples), ខ្សែអក្សរមួយដែលតំណាងឱ្យឈ្មោះឯកសារ ឬ URL, ឬទិន្នន័យ PCM ឥតដាក់បំលែង។ ប៉ារ៉ាម៉ែត្រ filename ត្រូវបានប្រើសម្រាប់បញ្ជាក់ឯកសារព្រមានដែលត្រូវផ្ទុកទិន្នន័យសម្លេងពីវា, និងប៉ារ៉ាម៉ែត្រ url ត្រូវបានប្រើសម្រាប់កំណត់ URL ដើម្បីទាញយកទិន្នន័យសម្លេងពីវា។ ប៉ារ៉ាម៉ែត្រ embed កំណត់ថាតើទិន្នន័យសម្លេងគួរត្រូវបានដាក់បញ្ចូលដោយប្រើ data URI ឬយោងពីប្រភពដើម។ ប៉ារ៉ាម៉ែត្រ rate បញ្ជាក់អត្រាសэмpling (sampling rate) នៃទិន្នន័យសម្លេង។ ប៉ារ៉ាម៉ែត្រ autoplay កំណត់ថាតើសម្លេងគួរចាប់ផ្តើមលេងដោយស្វ័យប្រវត្តិឬអត់។ ប៉ារ៉ាម៉ែត្រ normalize បញ្ជាក់ថាតើទិន្នន័យសម្លេងត្រូវបានធ្វើស្ដង់ដារ (rescaled) ទៅដល់ជួរតម្លៃអតិបរមាឬទេ។ ថ្នាក់ Audio ក៏ផ្តល់វិធីសាស្រ្តដូចជា reload ដើម្បីផ្ទុកឡើងវិញទិន្នន័យសម្លេងពីឯកសារ ឬ URL, និងសម្បត្តិដូចជា src_attr, autoplay_attr, និង element_id_attr ដើម្បីទាញយកសម្បត្តិដែលសមរម្យសម្រាប់ធាតុសម្លេងក្នុង HTML។
#
# សរុប មុខងារ និងថ្នាក់ទាំងនេះត្រូវបានប្រើសម្រាប់បកប្រែសម្លេងទៅជាអត្ថបទ, បង្កើតចម្លើយសម្លេងពី chatbot, និងបង្ហាញ និងលេងសម្លេងនៅក្នុងបរិបទ Jupyter Notebook។

# %%
#@title Run gradio app
def convert_to_text(audio_path):
  gpu=True
  if gpu:
    result = whisper_model.transcribe(audio_path,word_timestamps=True,fp16=True,language='English',task='translate')
  else:
    result = whisper_model.transcribe(audio_path,word_timestamps=True,fp16=False,language='English',task='translate')
  with open('scan.txt', 'w') as file:
    file.write(str(result))
  return result["text"]


import gradio as gr
from IPython.display import Audio, display
def run_text_prompt(message, chat_history):
    bot_message = phi_demo(message)
    edge_save_path=talk(bot_message)
    # print(edge_save_path)
    display(Audio(edge_save_path, autoplay=True))

    chat_history.append((message, bot_message))
    return "", chat_history


def run_audio_prompt(audio, chat_history):
    if audio is None:
        return None, chat_history
    print(audio)
    message_transcription = convert_to_text(audio)
    _, chat_history = run_text_prompt(message_transcription, chat_history)
    return None, chat_history


with gr.Blocks() as demo:
    chatbot = gr.Chatbot(label="Chat with Phi 3 mini 4k instruct")

    msg = gr.Textbox(label="Ask anything")
    msg.submit(run_text_prompt, [msg, chatbot], [msg, chatbot])

    with gr.Row():
        audio = gr.Audio(sources="microphone", type="filepath")

        send_audio_button = gr.Button("Send Audio", interactive=True)
        send_audio_button.click(run_audio_prompt, [audio, chatbot], [audio, chatbot])

demo.launch(share=True,debug=True)

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **សេចក្តីបដិសេធ**:
# ឯកសារនេះត្រូវបានបកប្រែដោយប្រើសេវាកម្មបកប្រែ AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ទោះយើងខំប្រឹងរក្សាការត្រឹមត្រូវក្តី សូមចំណាំថាការបកប្រែដោយស្វ័យប្រវត្តិអាចមានកំហុស ឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមក្នុងភាសាដើមគួរត្រូវបានគិតថាជាប្រភពដែលអាចទុកចិត្តបាន។ សម្រាប់ព័ត៌មានសំខាន់ៗ យើងសូមណែនាំឱ្យប្រើការបកប្រែដោយអ្នកបកប្រែមនុស្សដែលមានវិជ្ជាជីវៈ។ យើងមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកស្រាយខុសណាមួយដែលកើតឡើងពីការប្រើប្រាស់ការបកប្រែនេះទេ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
